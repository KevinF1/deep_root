# %% [markdown]
# # Generation of times series

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def create_random_serie(size=100):
    ts = np.random.normal(size=size)
    return ts

# %%
ts = create_random_serie(size=1000)

# %%
plt.plot(ts)
plt.show()
