# %% [markdown]
# # Generation of times series

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import deep_root.dynamic_generation as dynamic

# %%
d_trend = dynamic.create_noised_deterministic_trend(noise_lvl=1, start=1, trend=0.1, size=100, delta=1)
s_trend = dynamic.create_noised_stochastic_trend(noise_lvl=1, start=1, size=100)

# %%
plt.plot(d_trend)
plt.plot(s_trend)
